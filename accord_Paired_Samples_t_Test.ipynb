# %% [markdown]
# # APEX STATS Module: Paired Samples *t*-Tests
# Module by David Schuster and Michelle Baca Reinke
#
# Licensed under CC BY-NC-SA
#
# Release 1.5

# %% [markdown]
# ![Screenshot 2024-06-26 at 9.25.01 PM.png](data:image/png;base64,...)

# %% [markdown]
# Image generated using <a href="https://firefly.adobe.com/">Adobe Firefly</a>
#
# ## Part I. Start Here
# This module introduces the paired samples *t*-test.
#
# Arrows (<font color="red">➡</font>) indicate something for you to do as you work through this notebook. The first thing you should do is to save a copy.
#
# <font color="red">➡</font> **Create your own editable copy of this notebook**
# <details>
# <summary> 📋 Click for instructions</summary>
#
# ### <font color="red">➡</font> 1. Save a Copy
#
# This notebook is "view only," meaning that you can view it, but you cannot save any changes. To create your own editable copy, look towards the top of the notebook and click on `Copy to Drive`. This will cause a new tab to open with your own personal copy of the notebook.
#
# If you want to refer back to your copy in the future, you can find it in Google Drive in a folder called `Colab Notebooks`. Specifically, your copy of this notebook will be called: "Copy of Paired_Samples_t_Test" unless you rename it.
#
# ### <font color='red'>➡</font> 2. Change the File Name
#
# * After you saved your own copy, click into the title at the top of the webpage and **delete** the words "Copy of".
# * At the end of the title **insert a hyphen "-"** and then add your **name** according to your instructor's directions. For example, Lab 3 - Frequency Distributions - Smith, Jane.
# * This will make it easier for your instructor to find your work.
#
# ### <font color='red'>➡</font> 3. Change Notebook Settings
#
# Change your notebook settings so your outputs get saved. Watch the 45-second video that shows you how: http://somup.com/c3Qr0sU54S
#
# Complete the following:
#
# *   At the top of the webpage, click the **Notebook Settings** link. Or you can go to **EDIT** on the menu, then select "Notebook Settings".
# *   **Uncheck the checkbox** for "Omit code cell output when saving this notebook".
# ![colab notebook settings.jpg](data:image/jpeg;base64,...)
# *   Click **Save**.
#
# ### <font color='red'>➡</font> 4. Share with Your Instructor
#
# Once finished, share your completed notebook with your instructor using the `Share` button at the upper right.
#
# ### Important Tip About Working With Colab
#
# Like Google Sheets, Google Colab will save as you go. If you walk away from your Colab Notebook for an extended period of time, you may need to run all your cells again in order to pick up where you left off.
#
# ---

# %% [markdown]
# **New to Colab? Read this for how to run code cells and edit text cells**
#
# <details>
# <summary> 📋 Click for instructions</summary>
#
# Activities include both coding exercises and reflection questions.
# > <font color="red">➡</font> **Coding Activities** are found in code cells underneath the activity descriptions. To "run" a code cell, click on it, and either simultaneously hit **`Shift` + `Enter`** or click the **play button** `▶` button to the left of the cell.
#
# > <font color="red">➡</font> **Reflection Questions** are found in text cells. Double click on the text cells to edit the text. Type your answers underneath each question. When you are finished, click outside the cell to see your answers.
# * Bonus: For nicely formatted bullet points, type an asterisk **`*`**, add a space, and then type your answer!

# %% [markdown]
# ## Part II. Background
#
# <details>
# <summary>  📚  Click for recommended background reading </summary>
#
# A paired samples *t*-test, also known as the dependent samples t-test, compares the means of two related groups under different conditions, using hypothesis testing to determine if there is a significant difference between the measurements.
#
# This test is applicable when the same participants are measured twice under different conditions or when there are pairs of matched subjects. Put another way, we can use a paired samples *t*-test in one of the following situations:
#
# - We have two sets of related data of a continuous, quantitative variable.
# - The data comes from the same participants measured under two different conditions. For example, repeated measurements at two different points in time (e.g., before and after an intervention) where each participant will have two measures, time1 and time2.
# - The data are from different participants that are carefully matched based on certain characteristics (e.g., key demographic variables) to ensuring that each participant in one condition has a corresponding counterpart in the other condition, allowing for comparison.
#
#
#
# The following background is recommended before starting this module:
#
# 1. **Welcome to Colab** If you have not worked through the <a href="https://colab.research.google.com/drive/1zTk_n6BL8Tvdhaufq_FYNXK0dbvGKnxX?usp=sharing">Welcome to Colab</a> notebook yet, you should do that first.
#
# 2. It is helpful to know the basics of **descriptive statistics**, **the central limit theorem**, and **hypothesis testing**. We recommend completing APEX STATS modules on these topics.
#
# ### Learning Outcomes
#
# These exercises map onto several learning objective(s) for the C-ID descriptor for [Introduction to Statistics](https://c-id.net/descriptors/final/show/365). Upon successful completion of the course, you will be able to:
#
# * LO1: Interpret data displayed in tables and graphically
# * LO6: Calculate probabilities using normal and t-distributions
# * LO9: Determine and interpret levels of statistical significance including p-values
# * LO10: Interpret the output of a technology-based statistical analysis
# * LO12: Formulate hypothesis tests involving samples from one and two populations
# * LO13: Select the appropriate technique for testing a hypothesis and interpret the result
#
#
# Next, read through the activity and follow the steps indicated by the arrows.
#
# Read through this section before starting this module and consider the questions that follow.

# %% [markdown]
# ## Part III. Activities
#
# The following activities will use the life expectancy at birth measured from a sample of countries two decades apart, in 2008 and 2018, to illustrate the process of running and interpreting a paired samples *t*-test.
#
# We will ask a simple question of the data. Does life expectancy at birth differ significantly from 2008 to 2018? A paired samples *t*-test is appropriate for comparing data from the same participants (in this case, the same set of countries) across time. In this example, our participants are not people; they are countries.
#
# Life expectancy at birth refers to the average number of years that a newborn may be expected to live based on the mortality patterns for their birth year.

# %% [markdown]
# ### 1. Get Data
#
# Before you can begin these exercises, you need to run the code cell below, which will import the World Bank file and create a dataframe (i.e., spreadsheet) named `data`. After you run the cell, you will proceed to the next section to  preview the dataframe.

# %% [markdown]
# ### <font color="red">➡</font> Run the Cell to Set Up Example Data
#
# Use your preferred technique for running the cell below.
#
# <details>
# <summary> 📋 Click for trouble shooting help </summary>
#
# You should see the text "The data were loaded" underneath the code cell. If you see that, continue to the next section. If you come back to this notebook later, you will need to rerun this cell to load the data again.
#
# If you see the text "There was a problem loading the data," then the most likely explanation is a bug that is our fault. Let your instructor know the notebook is not working properly.
#
# </details>

# %%
# Import library
import pandas as pd

# Read data file: World Bank
data = pd.read_csv('https://raw.githubusercontent.com/vectrlab/apex-stats-datasets/main/healthnutritionandpopulation/example.csv')

# Handle errors
try:
    data
    print('The data were loaded.')
except NameError:
    print('There was a problem loading the data.')

# %% [markdown]
# ### <font color="red">➡</font> Run the Cell to Preview Data
#
# Next, we will generate a quick preview of the data you just loaded. Run the cell that follows. After you run the cell, you should see a table with rows and columns. Each row is a country and each column is a year (detailed in the next section).

# %%
# Preview Data
data

# %% [markdown]
# ### 2. Explore the Data
#
# Now that you have seen a preview, it is time to explore the dataframe! We will be using the following format to refer to each variable:
# `name of dataframe['column name']`
#
# - `data['y']`: Country name
# - `data['x']`: Life expectancy at birth in 2018, in years
# - `data['x1']`: Life expectancy at birth in 2008, in years (ten years earlier)
# - `data['x2']`: Life expectancy at birth in 1998, in years
# - `data['x3']`: Life expectancy at birth in 1988, in years
# - `data['x4']`: Life expectancy at birth in 1978, in years
# - `data['x5']`: Life expectancy at birth in 1968, in years
#
# For this module, the only variables we will need are `data['x']` and `data['x1']`.

# %% [markdown]
# ### <font color="red">➡</font> Run the Cell to Give the Variables Meaningful Names
#
# One of the ways real world data can be messy is when the variables have generic names. It will be clearer to write `data['exp2018']` and `data['exp2008']` instead of `data['x']` and `data['x1']`.
#
# Run the block below, which will rename these columns in the dataframe and show a preview of the revised dataframe.
#
# The following are the renamed column labels:
#
# - `data['y']`: `country`
# - `data['x']`: `exp2018`
# - `data['x1']`: `exp2008`
#
# After running this code block, all subsequent code will use the new variable names.

# %%
# Rename dataframe columns
data.columns = ['country', 'exp2018', 'exp2008', 'x2', 'x3', 'x4', 'x5']

# Preview data
data

# %% [markdown]
# ### 3. Decide on a One-Tailed or Two-Tailed Test
#
# Now that you have seen a preview, it is time to use the data.
#
# There are two ways to write hypotheses for *t*-tests. In a **one-tailed test**, we are testing for the presence of a **directional relationship**. For example, if we hypothesize that the mean life expectancy in 2018 will be greater than the mean life expectancy in 2008, we are predicting one direction. Similarly, if we hypothesized that mean life expectancy would be greater in 2008 compared to 2018, we would be prediciting an outcome in the other direction. The advantage is that our statistical test will be more sensitive (i.e., more statistical power) when running a one-tailed test. The disadvantage is that would not be able to test for *both* of these relationships at the same time.
#
# We would want to test for both if we do not strong have evidence that one measure is either more or less than the other. To look for a relationship without a direction, we need to use a **two-tailed test**. Two-tailed tests have the advantage of looking in both directions at a cost of some sensitivity (i.e., less statistical power).
#
#
# In this case, global trends have suggested that life expectancy across countries has been increasing across time. Medical, social, and economic advancements have been identified as factors that positively impact life expectancy. Therefore, we will use a one-tailed test in this example.
#
#
# To summarize, use a one-tailed test when you have a reason to predict the direction of the relationship before you start. Otherwise, use a two-tailed test. For our data, we will use a one-tailed test to test whether mean life expectancy in 2018 is greater than 2008.

# %% [markdown]
# ### 4. Write Hypotheses
#
# In a paired t-test, we are testing the difference between related observations. The hypotheses are stated in terms of the differences between the pairs. For each pair, we calculate $D=x−x_1$​, where:
#
# * $D$ is the difference between the paired observations.
# * $x$ is the value of the first observation (e.g., mean life expectancy in 2018).
# * $x_1$ is the value of the second observation (e.g., mean life expectancy in 2008).
#
# The mean of these differences, denoted as ${\mu_D}$, represents the average difference between the paired observations. The paired t-test then tests whether this mean difference is significantly different from zero.
#
# The one-tailed hypotheses for a paired samples t-test are:
#
# > $H_0: {\mu_D} ​≤ 0$
#
# > $H_a: {\mu_D} ​> 0$
#
#
# The null hypothesis ($H_0$) is that the mean difference in life expectancy between 2018 and 2008 is less than or equal to zero.
#
# The alternative hypothesis ($H_a$, sometimes labeled $H_1$) is that the mean difference in life expectancy between 2018 and 2008 is greater than zero. The alternative hypothesis is always the **logical complement** to the null hypothesis. If the null is true, then the alternative is false. If the null is false, then the alternative is true.
#
# If we had predicted an outcome in the other direction (that mean life expectancy would be greater in 2008 compared to 2018), then we would simply switch the direction of the signs in the null and alternative hypotheses.
#
#
# Although we do not need these right now, here is how we would have written hypotheses for two-tailed tests. Notice how the null hypothesis is always the logical complement of the alternative hypothesis. In the context of comparing life expectancy in 2008 and 2018, a two-tailed test would examine whether the mean life expectancy in 2018 is significantly different from that in 2008, without specifying whether it is higher or lower.
#
# > $H_0: {\mu_D} =  0$
#
# > $H_a: {\mu_D} \ne 0$

# %% [markdown]
# ### <font color="red">➡</font> Run the Cell to Conduct a Paired Samples *t*-Test

# %%
# Import library
from scipy import stats

# Paired samples t-test
results = stats.ttest_rel(
    data['exp2018'], data['exp2008'],
    alternative='greater'
    )

# Print results
print(
    f"""Results:
    t-statistic = {results.statistic}
    p-value = {results.pvalue}
    degrees of freedom = {results.df}
    """
    )

# %% [markdown]
# ###6. Interpret the Results
#
# Refer to the following to interpret the output above:
#
# * The *t* statistic indicates the magnitude of the mean difference between the paired samples relative to its standard error.
# * The *p*-value indicates whether the difference is statistically significant. Specifically, it represents the probability of observing this value of *t* if the null hypothesis were true (i.e., if there were no mean difference).
# * The degrees of freedom represents the number of values in a calculation that are free to vary. For the paired samples *t*-test, this is $N - 1$.

# %% [markdown]
# ### 7. Decide
#
# Our *p*-value leads us to our decision.
#
# <details>
# <summary>  📚  Click for recommended background reading </summary>
#
# When the mean difference is large, *t* is large and *p* is small (less than .05). This would mean a large enough mean difference was observed to get beyond the threshold of evidence. When this happens, we can claim there is a difference. The term for a mean difference that is large enough to reject the null hypothesis is a **statistically significant difference**.
#
# When we retain the null, our results are inconclusive. Retaining the null gives us no evidence, which can be confusing. When the mean difference is small, *t* is small and *p* is large (greater than .05). If we observed a small mean difference that was not enough to get us over our threshold of evidence, we cannot claim that there is no difference at all. At the same time, we cannot claim that there is even a small difference. The point of Null Hypothesis Testing (NHST) is to give us a guideline for how big of a difference is needed before we can call it a reliable difference.
#
# In summary, only rejecting the null allows us to make a conclusion.
#
# Only the *p*-value is needed to reject or retain. However, the values of *t*, *df*, mean difference, and Cohen's *d* (a measure of effect size) are useful values to add context to the *p*-value. For this reason, whenever you report a *p*-value to others, you should also include the values of *t*, *df*, mean difference, and Cohen's *d*.

# %% [markdown]
# ### 8. Mean Difference and Effect Size
#
# <details>
# <summary>  📚  Click for recommended background reading </summary>
#
# To quantify the average change between paired samples and assess the standardized effect size of the observed difference, we will calculate the mean difference and Cohen's *d* effect size. The mean difference is the average difference between our paired observations. Cohen's *d* provides a standardized measure of how large that difference is in standard deviations. These help us understand the practical significance and impact of the observed changes.
#
#
# The code in the next block will calculate these for you. For reference, these are the formulas for hand calculations.
#
# Mean Difference ($M_D$):
#
# >$D = x - x_1$
#
# >$M_D = \frac{\sum D}{N}$
#
# * $x$ and $x_1$ are the paired observations
# * $D$ is the difference for each pair
# * $N$ is the number of pairs
#
# Cohen's *d* ($d$):
#
# >$d = \frac{M_D}{s_D}$
#
#
# * $M_D$ is the mean difference
# * $s_D$ is the standard deviation of the differences

# %% [markdown]
# ### <font color="red">➡</font> Run the Cell to Calculate the Mean Difference and Cohen's *d*

# %%
# Import library
import numpy as np

# Calulate mean difference
difference = data['exp2018'] - data['exp2008']
mean_diff = np.mean(difference)


# Calculate standard deviation of differences
std_diff = np.std(difference, ddof=1)

# Calculate Cohen's d
cohens_d = mean_diff / std_diff

# Print results
print(
    f"""Results:
    mean difference = {mean_diff}
    Cohen's d = {cohens_d}
    """
    )

# %% [markdown]
# ### <font color="red">➡</font> Answer the Following Questions
#
#
# -Q1. What was your observed mean difference?
#
# *
#
#
# -Q2. What value of *t* did you find?
#
# *
#
#
# -Q3. What value of *p* did you find? Remember that you conducted a one-tailed (also called one-sided) test.
#
# *
#
#
# -Q4. Was *p* &lt; .05?
#
# *
#
#
# -Q5. Based on your *p*-value, is the correct decision to reject the null hypothesis or retain the null hypothesis?
#
# *
#
#
# -Q6. Did you put 0 for Q3? This is a misleading thing that computers do. A *p*-value can never be zero. When p-values are very small, they will show up as 0.0000 because the small digits are cut off. Whenever you see this, write it as *p* < .001 to reflect a very small *p*-value. Did you correct for this in Q3? If not, you can leave your response as is; however, write your p-value the correct way here:
#
#
#
# *
#
#
# -Q7. Reflect on our hypothesis and interpret the results in a real-world context. What do the observed mean difference and statistical values mean for life expectancy?
#
# *

# %% [markdown]
# ----
# ## Part IV. Summary
#
# - In this module, we ran a **paired samples t-test**.
# - This test requires two sets of related quantitative, continuous variables sampled from the same population (or matched pairs).
# - Before running a *t*-test, decide if a **one-tailed** or **two-tailed** test is more appropriate. Then, write the corresponding **null and alternative hypotheses**.
# - Our *p*-value will lead us to **reject** or **retain** the null hypothesis. Other values that help add context include $t$, $df$, $M_D$, and Cohen's $d$.
# - The mean difference and Cohen's $d$ effect size help us to understand the practical significance of statistical results.

# %% [markdown]
# ----
# ## Part V. Obtain a Link to Your Completed Notebook
#
# <details>
# <summary> 📋 Click for instructions</summary>
#
# Follow the steps below to get a shareable link appropriate for Canvas:
# * In the upper right of the screen, click on the button that says "Share"
# * In the resulting pop-up window, there are **two** things that you need to change:
#     * On the left, you'll see that your notebook is currently restricted. Click on the blue link underneath the word "restricted" to make the necessary changes.
#     * You should now see two dropdown menus. Click the one on the left and select "Anyone with the link"
#     * Next, click the dropdown on the right and select "Editor". This allows anyone with the link to make changes and comments in your notebook.
# * Now, you're sharing permissions are correct and your link is ready! Simply click "Copy link" and paste it into the relevant spot as directed by your instructor.
#
# The image below shows the step where you change the sharing permissions to "Editor":
# ![share link editor.png](data:image/png;base64,...)

# %% [markdown]
# ---
# ## Part VI. All Done, Congrats!
#
# Today you've not only ran a paired samples *t*-test, but you've also learned how to write some Python code. High five!
#
# <img src="https://live.staticflickr.com/3471/3904325807_8ab0190152_b.jpg" alt="High-five!" width="300"/>
#
# ["High-five!"](https://live.staticflickr.com/3471/3904325807_8ab0190152_b.jpg) by Nick J Webb is licensed under CC BY 2.0
